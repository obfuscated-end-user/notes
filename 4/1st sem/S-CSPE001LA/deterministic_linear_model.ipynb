# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# linear
ds1 = [
    np.array([3, 6, 9, 12, 15, 18]),
    np.array([14, 20, 26, 32, 38, 44]),
]

plt.scatter(ds1[0], ds1[1])

# %%
# not linear
ds2 = [
    np.array([1, 2, 3, 4, 5, 6, 7, 8]),
    np.array([21, 35, 57, 87, 125, 171, 225, 287]),
]

plt.scatter(ds2[0], ds2[1])

# %%
# linear
ds3 = [
    np.array([1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
    np.array([-0.5, 4.5, 9.5, 14.5, 19.5, 24.5, 29.5, 34.5]),
]

plt.scatter(ds3[0], ds3[1])

# %%
b = 12
I = (b * 275_000) - 100_000
I
# Out:
# 3200000

# %% [markdown]
# I = b * 275000 - 100000
#
# where:
# I = net revenue in usd over 1 year
# b = # of branches
# the constants represent the upfront costs of creating a new location
#
# will this model work for all those situations
# yes

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
# https://s3-eu-west-1.amazonaws.com/blog-ecotree/blog/0001/01/ad46dbb447cd0e9a6aeecd64cc2bd332b0cbcb79.jpeg
img = cv.imread("/content/test1.jpeg")

# %%
blur = cv.blur(img, (5, 5))
plt.subplot(121), plt.imshow(img), plt.title("Original")
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(blur), plt.title("Blurred")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv.blur(img, (5, 5), 100) # different standard deviation
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([])
plt.imshow(blur)

# %%
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
pip install sewar

# %%
from sewar import full_ref
from skimage import measure, metrics

# %%
gaussian_kernel = np.ones((3, 3), np.float32) / 25
conv_gaussian = cv.filter2D(blur, -1, gaussian_kernel, borderType=cv.BORDER_CONSTANT)
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([])
plt.imshow(conv_gaussian)

# %%
gaussian_kernel = np.ones((5, 5), np.float32) / 25
conv_gaussian = cv.filter2D(blur, -1, gaussian_kernel, borderType=cv.BORDER_CONSTANT)
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([])
plt.imshow(conv_gaussian)

# %%
gaussian_kernel = np.ones((7, 7), np.float32) / 25
conv_gaussian = cv.filter2D(blur, -1, gaussian_kernel, borderType=cv.BORDER_CONSTANT)
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([])
plt.imshow(conv_gaussian)

# %%
gaussian_kernel = np.ones((9, 9), np.float32) / 25
conv_gaussian = cv.filter2D(blur, -1, gaussian_kernel, borderType=cv.BORDER_CONSTANT)
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([])
plt.imshow(conv_gaussian)

# %%
gaussian_kernel = np.ones((19, 19), np.float32) / 25
conv_gaussian = cv.filter2D(blur, -1, gaussian_kernel, borderType=cv.BORDER_CONSTANT)
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([])
plt.imshow(conv_gaussian)

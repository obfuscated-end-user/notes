# %%
# !pip install transformers

# %%
from transformers import pipeline
import pandas as pd

food_classifier = pipeline(model="nateraw/food")

''' food_classifier = classifier("https://d2j6dbq0eux0bg.cloudfront.net/images/50740009/2063671529.jpg")
scores, labels = [data["score"] for data in test], [data["label"] for data in test]
max_score = max(scores)
best_pred = []
scores_labels = list(zip(scores, labels))
df1 = pd.DataFrame(test)

print(test)
print(scores_labels)
max(df1[["score", "label"]])
df1[["score", "label"]]
df1.iloc[0] '''
1
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# 1

# %%
from PIL import Image
import requests

images = [
    "https://d2j6dbq0eux0bg.cloudfront.net/images/50740009/2063671529.jpg",
    "https://qph.cf2.quoracdn.net/main-qimg-9ae5b2fe285748042c26c71f8765acac-lq", # SHIT
    "https://images.aws.nestle.recipes/resized/38a93505b258e61852c5c821ba1f55a1_nks-b3-d02_159_944_531.jpg",
    "https://thefoodietakesflight.com/wp-content/uploads/2020/08/e345f8_4b241ab6f490420e8232118200eb1ae1mv2.jpg",
    "https://hips.hearstapps.com/hmg-prod/images/delish-220524-chocolate-milkshake-001-ab-web-1654180529.jpg?crop=0.647xw:0.972xh;0.177xw,0.0123xh&resize=1200:*",
    "https://images.deliveryhero.io/image/fd-ph/LH/gi5z-hero.jpg",
    "https://yummykitchentv.com/wp-content/uploads/2021/10/Sequence-02.00_00_30_29.Still004.jpg",
    "https://12compassiong4.files.wordpress.com/2018/11/ricoslechon_large.jpg"
]

df_list = []

for image in images:
  food_df = pd.DataFrame(food_classifier(image))
  print(f"\n{food_df}")
  df_list.append(food_df)

image = Image.open(requests.get(images[4], stream=True).raw)
# image = Image.open(images[4])

# change the first number, the one between df_list and ["label"]
food = df_list[4]["label"].values[0]
# image.show()
image
# Out:
#       score      label
# 0  0.248442      sushi
# 1  0.180378      gyoza
# 2  0.103835  dumplings
# 3  0.076973   takoyaki
# 4  0.026235    waffles
#
#       score        label
# 0  0.935345       donuts
# 1  0.007892  onion_rings
# 2  0.005100     beignets
# 3  0.002908      churros
# 4  0.002796      falafel
#
#       score           label
# 0  0.855042       pork_chop
# 1  0.055794  baby_back_ribs
# 2  0.016314           steak
# 3  0.014613       foie_gras
# 4  0.005261   chicken_curry
#
#       score                label
# 0  0.587964             pad_thai
# 1  0.117140  spaghetti_bolognese
# 2  0.058601                ramen
# 3  0.046104           fried_rice
# 4  0.040911                  pho
#
#       score             label
# 0  0.978758  chocolate_mousse
# 1  0.005183         ice_cream
# 2  0.002817       panna_cotta
# 3  0.000925    chocolate_cake
# 4  0.000704     frozen_yogurt
#
#       score      label
# 0  0.890365    waffles
# 1  0.014858  apple_pie
# ...

# %%
# !pip install git+https://github.com/huggingface/transformers.git@main accelerate

recipe_generator = pipeline("text-generation", model="mrm8488/gpt2-finetuned-recipes-cooking_v2")
print(dir(recipe_generator))
response = recipe_generator(f"I'm trying to make {food}. Can you tell me how to make {food}, step by step?\n", max_length=300, num_return_sequences=1)
f"""{response[0]["generated_text"]}"""
recipe_generator(f"HuggingFace Cake:", max_length=300, num_return_sequences=1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# accelerate                       0.23.0
# aiohttp                          3.8.6
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.1
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.1.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.13.0
# ...

# %%
# google drive test
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !unzip /content/gdrive/MyDrive/images.zip -d images
# Out:
# Archive:  /content/gdrive/MyDrive/images.zip
#    creating: images/afritada/
#  extracting: images/afritada/3AANd9GcQ-loMhEFXDvCpJx6qJUQT4yInsoWOIVKvNFaLfNmRIawzLeTaI.jpg
#   inflating: images/afritada/3AANd9GcQ-MOPJr6N9psrg7EjMeyYd0v5gzjC_wQbdCI08MCgvRqcp7ceY.jpg
#   inflating: images/afritada/3AANd9GcQ0_qdDApj-QmZbKGkDDUSvj096qvm4T9eHBlYHko9FvQNY38ha.jpg
#   inflating: images/afritada/3AANd9GcQ4PyMxvmEEpNhp5iovpP2Yz8-bhZR3usZEazx9284_vM_mX7DS.jpg
#   inflating: images/afritada/3AANd9GcQ62OH2vKtJRgK9R_KnuwS_KTrdrnWmJN0pKsy3RaLSENRkraUi.jpg
#   inflating: images/afritada/3AANd9GcQ8t3Pu16etV0ghtID2XaGGWBZ5whvCeX9LLs9I1vTBKeUXf4Xb.jpg
#   inflating: images/afritada/3AANd9GcQ9BuDN1iA8VfA9KVfU-YzXMTIXDkO6zCIpvnBqhAP0mZNuEpZk.jpg
#   inflating: images/afritada/3AANd9GcQ9CKfaki4EwHPt5gvs23Wig4A-vuMZoCbRWxkyrlt2sWgmBa5l.jpg
#   inflating: images/afritada/3AANd9GcQaLZ00TFDcHQE1Av1nteuq5eMlqOqz4Ktk4nwUf0y12a68Iu3m.jpg
# ...

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.9 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset, Image

dataset = load_dataset("food101", split="train")
dataset[0]["image"]
# Out:
# ...
# Generating validation split:   0%|          | 0/25250 [00:00<?, ? examples/s]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x512>

# %%
dataset = load_dataset("food101", split="train", data_dir="/content/images").cast_column("image", Image(decode=False))
dataset[0]["image"]
# Out:
# ...
# Generating validation split:   0%|          | 0/25250 [00:00<?, ? examples/s]
# ...

# %%
# /content

# %cd /content
# Out:
# /content

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
obj = Series([3, 6, 9, 12])
obj
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
print(f"{obj.values}\n{obj.index}")
# Out:
# [ 3  6  9 12]
# RangeIndex(start=0, stop=4, step=1)

# %%
ww2_cas = Series([8700000, 4300000, 3000000, 210000, 400000], index=["US", "Germany", "China", "Japan", "Philippines"])
ww2_cas
# Out:
# US             8700000
# Germany        4300000
# China          3000000
# Japan           210000
# Philippines     400000
# dtype: int64

# %%
ww2_cas["Philippines"]
# Out:
# 400000

# %%
ww2_cas[ww2_cas > 400000]
# Out:
# US         8700000
# Germany    4300000
# China      3000000
# dtype: int64

# %%
"Japan" in ww2_cas
# Out:
# True

# %%
ww2_dict = ww2_cas.to_dict()
ww2_dict
# Out:
# {'US': 8700000,
#  'Germany': 4300000,
#  'China': 3000000,
#  'Japan': 210000,
#  'Philippines': 400000}

# %%
ww2_series = Series(ww2_dict)
ww2_series
# Out:
# US             8700000
# Germany        4300000
# China          3000000
# Japan           210000
# Philippines     400000
# dtype: int64

# %%
countries = ["US", "Germany", "China", "Japan", "Philippines", "Mexico"]
countries
# Out:
# ['US', 'Germany', 'China', 'Japan', 'Philippines', 'Mexico']

# %%
obj2 = Series(ww2_cas, index=countries)
obj2
# Out:
# US             8700000.0
# Germany        4300000.0
# China          3000000.0
# Japan           210000.0
# Philippines     400000.0
# Mexico               NaN
# dtype: float64

# %%
pd.isnull(obj2)
# Out:
# US             False
# Germany        False
# China          False
# Japan          False
# Philippines    False
# Mexico          True
# dtype: bool

# %%
pd.notnull(obj2)
# Out:
# US              True
# Germany         True
# China           True
# Japan           True
# Philippines     True
# Mexico         False
# dtype: bool

# %%
obj2
# Out:
# US             8700000.0
# Germany        4300000.0
# China          3000000.0
# Japan           210000.0
# Philippines     400000.0
# Mexico               NaN
# dtype: float64

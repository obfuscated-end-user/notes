# %%
# generate facebook captions
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch


def generate_caption(text):
    # Load the pre-trained GPT-2 model and tokenizer
    model = GPT2LMHeadModel.from_pretrained("distilgpt2")
    tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")


    # Tokenize the input text and add the beginning and end tokens
    input_ids = tokenizer.encode(text, return_tensors="pt")
    input_ids = torch.cat([input_ids, torch.tensor([tokenizer.eos_token_id])])


    # Generate the caption using the GPT-2 model
    output = model.generate(input_ids, max_length=20, num_return_sequences=1)
    caption = tokenizer.decode(output[0], skip_special_tokens=True)

    return caption


text = "The view from the top of the Eiffel Tower is breathtaking!"
caption = generate_caption(text)

print(caption)
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-45fcbf7f6c08> in <cell line: 25>()
#      23
#      24 text = "The view from the top of the Eiffel Tower is breathtaking!"
# ---> 25 caption = generate_caption(text)
#      26
#      27 print(caption)
#
# <ipython-input-1-45fcbf7f6c08> in generate_caption(text)
#      12     # Tokenize the input text and add the beginning and end tokens
#      13     input_ids = tokenizer.encode(text, return_tensors="pt")
# ...

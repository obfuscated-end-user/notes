# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
Grade = Series([67.45, 82.80, 86.54, 78.34], index=["Prelim", "Midterm", "Pre-final", "Final"])
Grade
# Out:
# Prelim       67.45
# Midterm      82.80
# Pre-final    86.54
# Final        78.34
# dtype: float64

# %%
Grade["Midterm"]
# Out:
# 82.8

# %%
Grade[Grade > 80]
# Out:
# Midterm      82.80
# Pre-final    86.54
# dtype: float64

# %%
Grade_dict = Grade.to_dict()
Grade_dict
# Out:
# {'Prelim': 67.45, 'Midterm': 82.8, 'Pre-final': 86.54, 'Final': 78.34}

# %%
indexes = ["Prelim", "Midterm", "Pre-final", "Final", "Final_Grade"]
Grade_Series = Series(Grade_dict, index=indexes)
Grade_Series
# Out:
# Prelim         67.45
# Midterm        82.80
# Pre-final      86.54
# Final          78.34
# Final_Grade      NaN
# dtype: float64

# %%
# !pip install git+https://github.com/nathanrchn/perplexityai.git
# Out:
# Collecting git+https://github.com/nathanrchn/perplexityai.git
#   Cloning https://github.com/nathanrchn/perplexityai.git to /tmp/pip-req-build-qbpnb50z
#   Running command git clone --filter=blob:none --quiet https://github.com/nathanrchn/perplexityai.git /tmp/pip-req-build-qbpnb50z
#   Resolved https://github.com/nathanrchn/perplexityai.git to commit 911666c27fde00f4ad5900eb74f27d7c76b18756
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: perplexityai
#   Building wheel for perplexityai (setup.py) ... done
#   Created wheel for perplexityai: filename=perplexityai-0.1-py3-none-any.whl size=6788 sha256=a7775a13246a7edaacf330badf11f1d64c4f40389992ad61dd4813005d4bcbb2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s72yohpw/wheels/cd/17/6d/7fa4e5dd5cdadec9642f7902b7c7f741d2f936d58bcf7944d5
# Successfully built perplexityai
# Installing collected packages: perplexityai
# Successfully installed perplexityai-0.1

# %%
''' from perplexity import Perplexity

# https://temp-mail.org/en/
# https://internxt.com/temporary-email
perplexity = Perplexity("hunter12@gmail.com")
answer = perplexity.search("What is the meaning of life?")
for a in answer:
  print(a)
perplexity.close() '''

# %%
from perplexity import Perplexity

perplexity = Perplexity("hunter12@gmail.com")
answer = perplexity.search("What is the meaning of life?")
for a in answer:
    print(a)
perplexity.close()
# Out:
# paste the link you received by email: https://www.perplexity.ai/api/auth/callback/email?callbackUrl=https%3A%2F%2Fwww.perplexity.ai&token=524a182a92bb15cf63134c1bd9b36d9867a4911c38c9dd056b0289713cd1464c&email=hunter12%40gmail.com
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-601dfd7c66a1> in <cell line: 3>()
#       1 from perplexity import Perplexity
#       2
# ----> 3 perplexity = Perplexity("hunter12@gmail.com")
#       4 answer = perplexity.search("What is the meaning of life?")
#       5 for a in answer:
#
# /usr/local/lib/python3.10/dist-packages/perplexity/perplexity.py in __init__(self, email)
#      26         self.email: str = email
#      27         self.t: str = self._get_t()
# ---> 28         self.sid: str = self._get_sid()
#      29
#      30         self.n: int = 1
#
# /usr/local/lib/python3.10/dist-packages/perplexity/perplexity.py in _get_sid(self)
#      78
#      79     def _get_sid(self) -> str:
# ---> 80         return loads(self.session.get(
#      81             url=f"https://www.perplexity.ai/socket.io/?EIO=4&transport=polling&t={self.t}"
#      82         ).text[1:])["sid"]
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from tuple import Tuple

from perplexity import Perplexity
def send_query_perp(query: str) -> Tuple[str, List[str]]:
    perplexity = Perplexity()
    perp_answer = perplexity.search(query)
    perp_answer_dicts = []
    sources = []
    for i in perp_answer:
        perp_answer_dicts.append(i)
    perplexity.close()
    try:
        print("web results: ", perp_answer_dicts[-1])
    except Exception as e:
        print("exc: ", e)
        print("web results: ", perp_answer_dicts)
    for source in perp_answer_dicts[-1]["web_results"]:
        sources.append(source['url'])
    return perp_answer_dicts[-1]["answer"], sources
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3844a4acb396> in <cell line: 2>()
#       1 from perplexity import Perplexity
# ----> 2 def send_query_perp(query: str) -> Tuple[str, List[str]]:
#       3     perplexity = Perplexity()
#       4     perp_answer = perplexity.search(query)
#       5     perp_answer_dicts = []
#
# NameError: name 'Tuple' is not defined

# %% [markdown]
# BERT-based QnA Model
# The Hugging Face transformers package is an immensely popular Python library providing pretrained models that are extraordinarily useful for a variety of natural language processing (NLP) tasks.
#
# Note: https://huggingface.co/models provides a selection of pre-trained models that can be used to quickly build prediction models for various nlp tasks. This demo uses the deepset/bert-basecased-squad2 model.

# %% [markdown]
# ---
#
# #Step 1: Install the required libraries

# %%
# !pip install transformers
# !pip install tensorflow
# Out:
# Requirement already satisfied: transformers in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (4.28.1)
# Requirement already satisfied: filelock in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (2023.3.23)
# Requirement already satisfied: requests in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests->transformers) (2022.12.7)
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tensorflow in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: tensorflow-macos==2.13.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.22.3)
# Requirement already satisfied: setuptools in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.54.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jagoodkid/miniforge3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.2)
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ---
#
# ## Step 2: Import the BertForQuestionAnswering class and use it to define a QnA prediction model based on your selected pretrained BERT model from huggingface.

# %%
from transformers import BertForQuestionAnswering
model = BertForQuestionAnswering.from_pretrained('deepset/bert-base-cased-squad2',force_download=True, resume_download=False)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %% [markdown]
# ---
#
# ## Step 3: Import the bert tokenizer class and use it to construct the tokenizer using the same BERT model. The tokenizer is used to prepare the string inputs for the prediction model by splitting the strings into sub-word token strings and converting them into transformer readable token IDs.

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('deepset/bert-base-cased-squad2')
# Out:
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/152 [00:00<?, ?B/s]

# %% [markdown]
# #Categories of special tokens used in the tokenization process and their corresponding token ID
#
# | Token | Meaning | Token ID |
# | --- | --- | --- |
# | **[PAD]** | Padding token, allows us to maintain same-length sequences (512 tokens for Bert) even when different sized sentences are fed in | 0 |
# | **[UNK]** | Used when a word is unknown to Bert | 100 |
# | **[CLS]** | Appears at the start of every sequence | 101 |
# | **[SEP]** | Indicates a seperator - used to indicate point between context-question and appears at end of sequences | 102 |
# | **[MASK]** | Used when masking tokens, for example in training with masked language modelling (MLM) | 103 |

# %%
tokenizer.encode("Import the bert tokenizer class and use it to construct the tokenizer using the same BERT model.", max_length=512, truncation =True, padding = True)
# Out:
# [101,
#  146,
#  24729,
#  3740,
#  1103,
#  1129,
#  3740,
#  22559,
#  17260,
#  1705,
#  1105,
#  1329,
#  1122,
#  1106,
#  9417,
#  1103,
#  22559,
#  17260,
#  1606,
#  1103,
#  1269,
#  139,
#  9637,
#  1942,
#  2235,
#  119,
#  102]

# %% [markdown]
# ---
#
# ## Step 4: Import the pipeline wrapper class and use it to construct the pipeline for a specific NLP task, in this case the Q&A task, by passing to it the built model and tokenizer.

# %%
from transformers import pipeline
qna = pipeline('question-answering', model=model, tokenizer=tokenizer)

# %% [markdown]
# ---
#
# ## Step 5: Upload the document to be used as context for the QnA along with the question that the BERT model will need to answer. The QnA ability of this model revolves around answering questions about a passage of text that it has read.

# %%
context = "The Intergovernmental Panel on Climate Change (IPCC) is a scientific intergovernmental body under the auspices of the United Nations, set up at the request of member governments. It was first established in 1988 by two United Nations organizations, the World Meteorological Organization (WMO) and the United Nations Environment Programme (UNEP), and later endorsed by the United Nations General Assembly through Resolution 43/53. Membership of the IPCC is open to all members of the WMO and UNEP. The IPCC produces reports that support the United Nations Framework Convention on Climate Change (UNFCCC), which is the main international treaty on climate change. The ultimate objective of the UNFCCC is to \"stabilize greenhouse gas concentrations in the atmosphere at a level that would prevent dangerous anthropogenic [i.e., human-induced] interference with the climate system\". IPCC reports cover \"the scientific, technical and socio-economic information relevant to understanding the scientific basis of risk of human-induced climate change, its potential impacts and options for adaptation and mitigation.\""
question = "What organization is the IPCC a part of?"
qna({'question': question,'context': context})
# Out:
# {'answer': 'United Nations,',
#  'end': 133,
#  'score': 0.4881569445133209,
#  'start': 118}

# %% [markdown]
# ---
#
# #Step 6: Plug-in QnA model to a basic user interdace and start testing the capability of the QnA Model

# %%
import textwrap
context = input("Enter Context Article: ")
dedented_text = textwrap.dedent(context).strip()
print("Context Article:\n")
print(textwrap.fill(dedented_text, width=120))

newcontext = 'y'
inquiry = input("\nType your question: ")
while (inquiry!='*'):
  answer = qna({'question': inquiry,'context': context})

  print("Answer found: "+ answer['answer'])
  print("At Index :", answer['start']," - ",answer['end'])
  print("with Probability:", answer['score'],"\n")
  inquiry = input("Enter another question (* to stop):")
# Out:
# Enter Context Article: ?
# Context Article:
#
# ?
#
# Type your question: *
